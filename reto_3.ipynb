# %%
nombre_cultivo = int(input("Ingrese el nombre del cultivo:"))
ingreso_dias_mantenimiento = input("Ingrese el número de días de mantenimiento:")
horario_mantenimiento = input("Ingrese el horario de mantenimiento (formato 24 horas):")
ingreso_dias_regado = input("Ingrese el número de días de riego del cultivo:")
horario_regado= input("Ingrese el horario de riego (formato 24 horas):")
ingreso_dias_abono = input("Ingrese el número de días de abonado del cultivo:")
horario_abono = input("Ingrese el horario de abonado (formato 24 horas):")
etapa_1="De a 5 a 30 dias"
etapa_2="De 31 a 60 dias"
etapa_3="De 61 a 90 dias"
etapa_4="De 91 a 120 dias"
etapa_5="De 121 a 150 dias"
switcch = {}
