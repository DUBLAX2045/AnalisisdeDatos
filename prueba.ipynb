# %%
vendedores = ["Juan", "Ana", "Pedro", "Luisa"]
print(vendedores)

vendedores.append("Carlos")
print(vendedores)
type(vendedores)

vendedores[1]="Maria"
vendedores[2]*=5
vendedores[1]+=" Gomez"
print(vendedores)
print(vendedores[2])

numeros=[10,20,30,40,50]
numeros[2]*=5
print(numeros[2])
# Out:
# ['Juan', 'Ana', 'Pedro', 'Luisa']
# ['Juan', 'Ana', 'Pedro', 'Luisa', 'Carlos']
# ['Juan', 'Maria Gomez', 'PedroPedroPedroPedroPedro', 'Luisa', 'Carlos']
# PedroPedroPedroPedroPedro
# 150

# %%
4+9
# Out:
# 13

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
numero_motos1=20
numero_motos2=30
total_motos=numero_motos1+numero_motos2
print("El total de motos es:",total_motos)
# Out:
# El total de motos es: 50
