# %% [markdown]
# #### Ejercicios de pandas
#
# Notebook con ejemplos practicos para cada punto.

# %% [markdown]
# ### 1.Introduccion a pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### 2.Series y DataFrames

# %%
s = pd.Series([10, 20, 30, 10], index=['a','b','c', 'd'])

#print(s.head(1))

#print(s.tail(1))
#print(s.shape)
#print(s.index)
#print(s.info)
#print(s.describe())
print(s)
# Out:
# count     4.000000
# mean     17.500000
# std       9.574271
# min      10.000000
# 25%      10.000000
# 50%      15.000000
# 75%      22.500000
# max      30.000000
# dtype: float64
# a    10
# b    20
# c    30
# d    10
# dtype: int64

# %%
df = pd.DataFrame({'pais':['MX','AR','MX'], 'ventas':[100,200,150]})

#print(df.head(1))
#print(df.tail(1))
#print(df.shape)
#print(df.index)
#print(df.info)
#print(df.describe())
#print(df.dtypes)
# Out:
# pais      object
# ventas     int64
# dtype: object

# %% [markdown]
# ### 3.Importacion y limpieza

# %%
#url="https://github.com/Twoeme/Prueba2/raw/refs/heads/main/Pandas_Class/layoffs.csv"
df = pd.read_csv(url)
#df = pd.read_excel(url)#sep=";"
print(df)
